# %%
listanumeros=['1','2','3','4','5']
for i  in listanumeros:
    print(f'{str(10*i)}')



print('.'.join([str(10*i) for i in listanumeros]))
# Out:
# 1111111111
# 2222222222
# 3333333333
# 4444444444
# 5555555555
# 1111111111.2222222222.3333333333.4444444444.5555555555

# %%
a = "Me gusta comer 5 patatas!     "
b = "     Me llamo Ralph, mi edad es 4    "

c = a.strip()+ " "+ b.strip()
d = c.split(',')
print(d)
# Out:
# ['Me gusta comer 5 patatas! Me llamo Ralph', ' mi edad es 4']

# %%
a = '2'

print(eval(a))
# Out:
# 2

# %%
import main

main.main()
# Out:
# Initial conditions
#  AstroList(astros = [Astro(earth, position: [1.496e+11 0.000e+00 0.000e+00], speed: [    0.  29783.9     0. ], mass: 5.97e+24)], fixed_astros = [Astro(sun, position: [0. 0. 0.], speed: [0. 0. 0.], mass: 1.98847e+30)])
#
# Parameters:
# Delta time: 3600.0
# Number of steps: 8766
# Interval for printing energy: 10000
# interval print coordinates: 10000
# Plot skip steps:100
# Use velocity read: True
# New year!: [0.04166667] day
# New year!: [365.20833333] day
# New year!: [365.25] day
# Variation of the energy: -3.549596019668977e-11
